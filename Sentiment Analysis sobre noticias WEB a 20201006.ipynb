# %% [markdown]
# ## Análisis de sentimientos expresados en noticias WEB

# %%
### ######################################
### Sentiment Analysis sobre noticias web
### Jose Maria de Cuenca
### ######################################

# Carga librerias y funciones
import re # Librería para manejo de expresiones regulares en el lenguaje natural
import string # Librería para manejo de cadenas
import nltk # Librería para procesamiento del lenguaje natural

from nltk.corpus import stopwords # Función adicional NLTK para identificar palabras irrelevantes
from textblob import TextBlob # Funcion para análisis de sentimientos
from urllib.request import urlopen as uReq # Permite hacer requerimientos a webs
from bs4 import BeautifulSoup as soup # Funcion para extraer datos desde textos en HTML y XML

# %% [markdown]
# ### Carga de la prensa a analizar

# %%
# Defino enlace a pagina de noticias
# Idealmente la hemeroteca de un periodo local, que hable de nosotros, con noticias ordenadas por fecha
# Para este ejemplo, el decano de la prensa en la ciudad de Valladolid, y el servicio de aguas en ella, Aquavall.
my_url = 'https://www.elnortedecastilla.es/hemeroteca/aquavall.html?order=-fecha'

# Utilizamos la libreria urlopen (as uReq) de urllib.request para abrir sesion y leer las noticias
uClient = uReq(my_url)
page_html = uClient.read()

# Cierro la conexion a la pagina
uClient.close()

# Cargo el contenido de la pagina en un objeto soup, realizando su análisis sintáctico para HTML
page_soup = soup(page_html, 'html.parser')

# %%
# El objeto soup permite localizar cada seccion de la página HTML, por ejemplo títulos, etiquetas, etc.
print(page_soup)
# Out:
# <!DOCTYPE html>
# <html lang="es-ES"><head><meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQcDVFBRCRACXVRUBQQGUlQ=",licenseKey:"c72ce647f9",applicationID:"295625140"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(i(window),i(f.prototype)),a.on(u+"-start",function(t,e){var n=t[1],r=s(n,"nr@wrapped",function(){function t(){if("function"==typeof n.handleEvent)return n.handleEvent.apply(n,arguments)}var e={object:t,"function":n}[typeof n];return ...
#         window.vocento = {
#             __PROVIDER__: {
#                 paywall: {
#                                                                               },
#                 rtim: {
#                                     },
#                 adbd: {
#                     deviceType: 'desktop',
#                     geo: {
#                         areaCode: '',
#                         city: '',
#                         country: '',
#                         countryCode: 'ES',
#                         dma: '',
#                         fips: '',
#                         lat: '',
#                         lng: '',
#                         msa: '',
#                         pmsa: '',
#                         regionCode: '',
#                         timezone: ''
#                     },
#                     network: {
#                         name: '',
#                         type: '',
#                         throughput: ''
#                     }
#
#                 }
#             },
#             config: {
#                 alerts: { pushServiceUrl: '//push.elnortedecastilla.es/list_notificaciones.php', appKey: '39955412156cb48e017d973.82425470', workerPath:'/comun/pushservice/ws/worker.min.js', editions: {} },
#                 multimedia: {
#                     videoplayer: {
#                         serviceUrl: '//api-video-player.vocento.com'
#                     }
#                 },
#                 paywall: {
#                                         enabled: true,
#                     options: {"site":"elnortedecastilla","makeCall":true,"applyRestrictions":true,"isTrialActive":false,"maxConcurrentSessions":"2|4","urlIosApp":"","urlAndroidApp":"","urlMoreInfo":"","urlFreeTest":"","labelButtonFreeTest":"\u00a1 Lo quiero!","urlSubscribe":"https://areapersonal.elnortedecastilla.es/suscripcion/","labelButtonSubscribe":"\u00a1 Lo quiero!","urlNewsletter":"https://areapersonal.elnortedecastilla.es/servicios/newsletters.html","urlExtendedRate":"","v2":true}
#                                     },
#                 scribblelive: {
#                     templatesUrl: '//static.vocento.com/scribble-live/latest/templates'
#                 },
#                 starred: {
#                     serviceUrl: 'https://areapersonal.elnortedecastilla.es/servicios/api/v1/articulo',
#                     templatesUrl: '//static.vocento.com/starred/latest/templates'
#                 },
#                                 vam: {
#                     media: {"lastUpdate":"02-10-2020 10:53:15","lastUser":"lfbravo","activo":true,"defineSlot":true,"dispositivos":["desktop","mobile","app"],"enableAmazonAds":false,"enableKrux":true,"enableTopics":true,"enableTpag":false,"excepciones":{"\/gente-estilo\/actriz-tania-carrasco-20170619104840-nt.html":{"OAS":{"desktop":{"portada":"\/4900\/vocento.nortecastilla\/gente-estilo\/gpolicy","noticia":"\/4900\/vocento.nortecastilla\/gente-estilo\/gpolicy","galeria":"\/4900\/vocento.nortecastilla\/gente-estilo\/gpolicy","video":"\/4900\/vocento.nortecastilla\/gente-estilo\/gpolicy"},"mobile":{"portada":"\/4900\/webm.NORTEDECASTILLA\/gente-estilo\/gpolicy","noticia":"\/4900\/webm.NORTEDECASTILLA\/gente-estilo\/gpolicy","galeria":"\/4900\/webm.NORTEDECASTILLA\/gente-estilo\/gpolicy","video":"\/4900\/webm.NORTEDECASTILLA\/gente-estilo\/gpolicy"}},"fecha_fin":0,"fecha_in":"1498138440","targetings":[],"priorizadas":{"desktop":[],"mobile":[],"app":[]},"retrasadas":{"desktop":[],"mobile":[],"app":[]},"posicion_desktop":{"backcss":{"desactivadoen":[],"programaciones":[]},"boton_local":{"desactivadoen":[],"programaciones":[]},"boton_native":{"desactivadoen":[],"programaciones":[]},"cintillo_local":{"desactivadoen":[],"programaciones":[]},"layer_inpage":{"desactivadoen":[],"programaciones":[]},"megabanner":{"desactivadoen":[],"programaciones":[]},"megabanner_dos":{"desactivadoen":[],"programaciones":[]},"robapaginas":{"desactivadoen":[],"programaciones":[]},"robapaginas_dos":{"desactivadoen":[],"programaciones":[]},"robapaginas_dos_local":{"desactivadoen":[],"programaciones":[]},"robapaginas_local":{"desactivadoen":[],"programaciones":[]},"skyscraper_der":{"desactivadoen":[],"programaciones":[]},"skyscraper_izq":{"desactivadoen":[],"programaciones":[]}},"posicion_mobile":{"backcss":{"desactivadoen":[],"programaciones":[]},"boton_native":{"desactivadoen":[],"programaciones":[]},"layer_inpage":{"desactivadoen":[],"programaciones":[]},"megabanner":{"desactivadoen":[],"programaciones":[]},"robapaginas":{"desactivadoen":[],"programaciones":[]},"robapaginas_dos":{"desactivadoen":[],"programaciones":[]},"robapaginas_dos_local":{"desactivadoen":[],"programaciones":[]},"robapaginas_local":{"desactivadoen":[],"programaciones":[]}},"posicion_app":[]}},"filteredPositions":{"desktop":{"all":["layer_inpage","megabanner","skyscraper_der","skyscraper_izq","robapaginas_tres","robapaginas_cinco","megabanner_tres","boton_local","cintillo_local","boton_dos","boton_tres","robapaginas_tres_local","boton_uno_local","boton_native_dos","boton_dos_local","robapaginas_cuatro_local","boton_tres_local","megacintillo_local","boton_uno","boton_native_tres","boton_native_cuatro","robapaginas_seis","robapaginas_siete","robapaginas_nueve","megabanner_tres_local","megabanner_cinco_local","robapaginas_diez_local","robapaginas_ocho_local","robapaginas_siete_local","robapaginas_cinco_local"],"galeria":["megabanner_dos","seed_tag"],"noticia":["megabanner_dos"],"portadilla":["megabanner_dos"],"video":["megabanner_dos"]},"mobile":{"all":["layer_inpage","megabanner","robapaginas_tres","robapaginas_cinco","megabanner_tres","boton_local","cintillo_local","boton_dos","boton_tres","robapaginas_tres_local","boton_uno_local","noticia_patrocinada","boton_native_dos","boton_dos_local","robapaginas_cuatro_local","boton_tres_local","megacintillo_local","boton_uno","boton_native_tres","boton_native_cuatro","robapaginas_seis","robapaginas_siete","boton_native_liga","robapaginas_nueve","megabanner_tres_local","megabanner_cinco_local","robapaginas_diez_local","robapaginas_ocho_local","robapaginas_siete_local","robapaginas_cinco_local"],"galeria":["boton_native_data","robapaginas","robapaginas_local","robapaginas_dos","robapaginas_dos_local","promociones","megabanner_dos","robapaginas_combinado_local","robapaginas_combinado_dos_local","seed_tag"],"noticia":["boton_native_data","robapaginas","robapaginas_local","robapaginas_dos","robapaginas_dos_local","promociones","megabanner_dos","roba ...
#                     options: {"lastUpdate":"2020-10-02 16:03:39","lastUser":"cron","multimedia":{"ads":{"prerolls":1,"postrolls":1},"hb":{"enable":true,"adUnits":{"desktop":[{"code":"preroll","mediaTypes":{"video":{"context":"instream","playerSize":[640,480]}},"bids":[{"bidder":"appnexus","params":{"placementId":18208871,"video":{"skippable":true,"playback_methods":["auto_play_sound_off"]}}}]},{"code":"postroll","mediaTypes":{"video":{"context":"instream","playerSize":[640,480]}},"bids":[{"bidder":"appnexus","params":{"placementId":18208872,"video":{"skippable":true,"playback_methods":["auto_play_sound_off"]}}}]}],"mobile":[{"code":"preroll","mediaTypes":{"video":{"context":"instream","playerSize":[640,480]}},"bids":[{"bidder":"appnexus","params":{"placementId":18208931,"video":{"skippable":true,"playback_methods":["auto_play_sound_off"]}}}]},{"code":"postroll","mediaTypes":{"video":{"context":"instream","playerSize":[640,480]}},"bids":[{"bidder":"appnexus","params":{"placementId":18208932,"video":{"skippable":true,"playback_methods":["auto_play_sound_off"]}}}]}]}}},"OAS":{"desktop":{"portada":"\/4900\/vocento.nortecastilla\/hemeroteca\/portada","noticia":"\/4900\/vocento.nortecastilla\/hemeroteca","galeria":"\/4900\/vocento.nortecastilla\/hemeroteca\/galerias","video":"\/4900\/vocento.nortecastilla\/hemeroteca"},"mobile":{"portada":"\/4900\/webm.NORTEDECASTILLA\/hemeroteca\/portada","noticia":"\/4900\/webm.NORTEDECASTILLA\/hemeroteca","galeria":"\/4900\/webm.NORTEDECASTILLA\/hemeroteca\/galerias","video":"\/4900\/webm.NORTEDECASTILLA\/hemeroteca"},"app":{"portada":"\/4900\/app.NORTEDECASTILLA\/hemeroteca\/portada","noticia":"\/4900\/app.NORTEDECASTILLA\/hemeroteca","galeria":"\/4900\/app.NORTEDECASTILLA\/hemeroteca\/galerias","video":"\/4900\/app.NORTEDECASTILLA\/hemeroteca"}},"posicion_desktop":{"boton_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"boton_native":{"programada":true,"programaciones":[],"desactivadoen":[]},"boton_native_dos":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"100"},"cintillo_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"layer_inpage":{"programada":true,"programaciones":[],"desactivadoen":["portada","galeria","video"]},"megabanner":{"programada":true,"programaciones":[],"desactivadoen":[]},"megabanner_dos":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"100"},"megabanner_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"megabanner_tres":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"500"},"patrocinio1":{"programada":true,"programaciones":[],"desactivadoen":[]},"robapaginas":{"programada":true,"programaciones":[],"desactivadoen":[]},"robapaginas_dos":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"100"},"robapaginas_dos_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"robapaginas_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"robapaginas_tres":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"100"},"robapaginas_tres_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"skyscraper_der":{"programada":true,"programaciones":[],"desactivadoen":[]},"skyscraper_izq":{"programada":true,"programaciones":[],"desactivadoen":[]},"robapaginas_cuatro_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"noticia_patrocinada":{"programada":true,"programaciones":[],"desactivadoen":[]},"megacintillo_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"promociones":{"programada":true,"programaciones":[],"desactivadoen":[]},"boton_native_tres":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"100"},"boton_native_cuatro":{"programada":true,"programaciones":[],"desactivadoen":[],"offset":"100"},"seed_tag":{"programada":true,"programaciones":[],"desactivadoen":[]}},"posicion_mobile":{"boton_local":{"programada":true,"programaciones":[],"desactivadoen":[]},"boton_native":{"pr ...
#                     pageType: "portada",
#                     newsId: ""
#                 },
#                                 vocuser: {
#                     url: {
#                         voccoreServiceUrl: '//voccore.elnortedecastilla.es/',
#                         prospectServiceUrl: '//newsletters.vocento.com/'
#                     },
#                     comments: {
#                                                     premiumComments: true,
#                                                 options: {categoryID: 'elnortedecastilla'},
#                         template: {
#                             commentsPlugin: "<div class=\"voc-comments-container\"><div class=\"container voc-comments-form\"><form class=\"form-horizontal\"><div class=\"gig-comments-composebox\"></div></form></div><div class=\"container voc-comments-opinion\"><div class=\"voc-comments-data\"><div class=\"col-xs-12 col-sm-6 voc-left\"><div class=\"gig-comments-header\"></div></div><div class=\"col-xs-12 col-sm-6 voc-right\"><div class=\"gig-comments-updates\"></div></div></div><div class=\"gig-comments-comments\"></div><div class=\"gig-comments-more voc-comments-more\">Ver más comentarios</div></div></div>",
#                             header: "<div class=\"gig-comments-sort voc-order\">Ordenar</div>",
#                             updates: "<div class=\"voc-updates\"><div class=\"gig-comments-updates-text\"></div><div class=\"gig-comments-updates-link\"></div></div>",
#                             composebox: "<div class=\"gig-composebox-editor\"></div><div class=\"voc-buttons\"><button type=\"button\" class=\"gig-composebox-post voc-send\" data-voc-vtm-id=\"btncomentar\" data-voc-vtm-info=\"enviar-comentario\">Enviar</button><div class=\"gig-composebox-login\"><div class=\"gig-composebox-site-login\">Iniciar Sesión</div></div><div class=\"gig-composebox-logout\">Cerrar Sesión</div>",
#                             comment: "<div class=\"voc-comments-name row\"><i class=\"voc-icons answer-icon\"></i><figure class=\"gig-comment-photo col-xs-2 col-sm-1\"></figure><div class=\"voc-name-left\"><div class=\"gig-comment-username\"></div><span class=\"gig-comment-time voc-clock\"></span></div><div class=\"voc-comment\"><div class=\"gig-comment-body\"></div></div><div class=\"voc-comments-social\"><div class=\"voc-social-left\"><a class=\"gig-comment-replyLink voc-reply\">Responder</a><a class=\"gig-comment-shareLink voc-reply\">Compartir</a></div><div class=\"voc-social-right\"><a class=\"gig-comment-vote-pos\"></a><a class=\"gig-comment-vote-neg\"></a></div></div><div class=\"gig-comment-replybox\"></div></div><div class=\"gig-comment-replies voc-comments-name voc-answer row\"></div>"
#                         }
#                     },
#                     urls: {
#                       catalog: 'https://catalogo-newsletters.vocento.com/',
#                       voccore: 'https://voccore.'
#                     },
#                     freezone: {
#                       subscriptionUrl: 'https://areapersonal.<medio.tld>/suscripcion/',
#                       newsletterUrl: 'https://areapersonal<medio.tld>/servicios/newsletters.html'
#                     }
#                 },
#                 vtm: {
#                     legacyTracker: false,
#                     trackerUrl: '//metrics.elnortedecastilla.es',
#                     evdabEnabled: false
#                 },
#                 relatedContent: {
#                     recommendationId: '',
#                     trackId: ''
#                 },
#                 lottery: {
#                     serviceUrl: 'https://api-lottery.vocento.com'
#                 },
#                 rtim: {
#                     articleId: '',
#                     section: '',
#                     category: '',
#                     authors: '',
#                     site: 'elnortedecastilla',
#                     tags: '',
#                     adblock: false,
#                     Meter: 'No',
#                     Extra: 'No',
#                     webtype: '',
#                     Origen: '',
#                     service: 'web'
#                 },
#                 widgets: {
#                     serviceUrl: 'https://voc.evolok.net/acd/api/3.0'
#                 }
#             },
#             site: {
#                 env: 'pro',
#                 group: 'ppll',
#                 subdomain: 'www',
#                 tlddomain: 'elnortedecastilla.es',
#                 media: 'elnortedecastilla',
#                 name: 'El Norte de Castilla',
#                 parent: '',
#                 editions: {
#                     hasEditions: false,
#                     editions: [],
#                     main: '',
#                     current: '',
#                     queryString: ''
#                 },
#                 content: {
#                                         section: '',
#                     newsId: '',
#                     title: '',
#                                                             firstPublicationDate: ''
#                                                         }
#             }
#         };
#     </script><script data-cmp="true" data-cmp-position="bottom" data-gdpr-migrate="squido-cookie-message" src="//static.vocento.com/voonto2/latest/voonto.js"></script><script>
#
#     window.ns_site = window.__VOONTO__.lookup('vocento.site').media;
#     window.voc_se = 'hemeroteca';
#     window.voc_s1 = '';
#     window.voc_s2 = '';
#     window.voc_s3 = '';
#     window.voc_s4 = '';
#     window.voc_tn = 'resultados';
#     window.voc_tc = 'hemeroteca';
#     window.voc_tcnew = 'hemeroteca';
#     window.voc_ed = window.__VOONTO__.lookup('vocento.site.editions').current;
#     window.voc_au = '';
#     window.voc_or = '';
#     window.voc_pr = 1;
#     window.voc_fep = '';
#     window.voc_fem = '';
#     window.voc_pl = ''; //TODO FIXME: from public fn
#     window.voc_tusr = window.__VOONTO__.getUserType();
#     window.voc_idi = 'es';
#     window.voc_hl = 'no';
#
# </script><script data-analytics-id="ppll_pro" data-legacy-adbd="true" data-legacy-comscore="7715761" data-legacy-krux="qxoborp8n" data-legacy-tracker="true" data-property-id="7d7c0790761bf4e65ff128b37ff7d599996ca047" src="//static.vocento.com/tag-manager/latest/vtm.js"></script><!-- GTM --><script>(function(w,d,s,l,i){w[l]=w[l]||[];var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-MJKFH6');</script><!-- GTM --><script>
#       var search = 'aquavall';
#       var res = search.split(" ");
#       var total = "";
#       var errorBusqueda = '';
#       var tipoBuscador = '';
#       if (res.length == 1) {
#         total = search;
#       } else {
#         res.forEach(function (i, idx, array) {
#           if (idx === array.length - 1) {
#             total += i;
#           } else {
#             total += i + ",";
#           }
#         });
#       }
#
#       TagManager.ready.then(function () {
#         var scriptTag = 'archive-result';
#         var typeTag = 'undefined';
#         var cookieADB = 'squido-adbd';
#         var capaA = 'capa-hemeroteca';
#         var capaB = 'pop-up';
#         var origenTags = 'undefined';
#
#         var results = document.querySelector('.voc-hemeroteca-num-results');
#         if (results) {
#           if (parseInt(results.textContent) == 0) {
#             errorBusqueda = 'cero-resultados';
#           }
#         }
#
#         var app = Voonto.getInstance();
#         var hasCookie = document.cookie.indexOf(cookieADB) > -1;
#         var hasTopic = document.referrer.indexOf(typeTag) > -1;
#         var promise = Promise.all([
#           app.when('blockadblock:ready'),
#           app.when('evdab:ready'),
#         ]);
#
#               resolvePromiseForArchiveResultContent(promise, hasCookie, capaA, total, errorBusqueda);
#         });
#
#       function resolvePromiseForMultimediaContent(promise) {
#         promise.then(function () {
#           TagManager.set({slot: 1}).track();
#         });
#       }
#
#       function resolvePromiseForCoverContent(promise, hasCookie, capaA, capaB) {
#         promise.then(function ([res1, res2]) {
#           if ((res1 || res2) && hasCookie) {
#             TagManager.set({capasMostradas: capaA}).track();
#           } else if ((res1 || res2) && !hasCookie) {
#             TagManager.set({capasMostradas: capaB}).track();
#           } else {
#             TagManager.track();
#           }
#         });
#       }
#
#       function resolvePromiseForSubCoverContent(promise, hasCookie, capaA, capaB) {
#         promise.then(function ([res1, res2]) {
#           if ((res1 || res2) && hasCookie) {
#             TagManager.set({capasMostradas: capaA}).track();
#           }
#           if ((res1 || res2) && !hasCookie) {
#             TagManager.set({capasMostradas: capaB}).track();
#           }
#         });
#       }
#
#       function resolvePromiseForNewsContent(promise, hasTopic, capaA, origenTags) {
#         promise.then(function ([res1, res2]) {
#           if (res1 || res2 && hasTopic) {
#             TagManager.set({capasMostradas: capaA, origenTags: origenTags}).track();
#           } else if (res1 || res2 && !hasTopic) {
#             TagManager.set({capasMostradas: capaA}).track();
#           } else if (hasTopic) {
#             TagManager.set({origenTags: origenTags}).track();
#           } else {
#             TagManager.track();
#           }
#         });
#       }
#
#       function resolvePromiseForMediaContent(promise, capaA) {
#         promise.then(function ([res1, res2]) {
#           if (res1 || res2) {
#             TagManager.set({capasMostradas: capaA, slot: 1}).track();
#           } else {
#             TagManager.set({slot: 1}).track();
#           }
#         });
#       }
#
#       function resolvePromiseForArchiveResultContent(promise, hasCookie, capaA, total, errorBusqueda) {
#         promise.then(function ([res1, res2]) {
#           if ((res1 || res2) && hasCookie) {
#             TagManager.set({
#               capasMostradas: capaA,
#               keyword: total,
#               tipoBuscador: 'hemeroteca',
#               errorBusqueda: errorBusqueda
#             }).track();
#           } else if ((res1 || res2) && !hasCookie) {
#             TagManager.set({
#               capasMostradas: capaB,
#               keyword: total,
#               tipoBuscador: 'hemeroteca',
#               errorBusqueda: errorBusqueda
#             }).track();
#           } else {
#             TagManager.set({
#               keyword: total,
#               tipoBuscador: 'hemeroteca',
#               errorBusqueda: errorBusqueda
#             }).track();
#           }
#         });
#       }
# </script><link href="//static2.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/favicon.ico" rel="icon"/><link href="//static2.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="//static2.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="//static1.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="//static3.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="//static3.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="//static2.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="//static2.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="//static1.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/><meta content="//static1.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/smalltile.png" name="msapplication-square70x70logo"/><meta content="//static3.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/mediumtile.png" name="msapplication-square150x150logo"/><meta content="//static.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/widetile.png" name="msapplication-wide310x150logo"/><meta content="//static3.elnortedecastilla.es/squido/latest/assets/icons/el-norte-de-castilla/largetile.png" name="msapplication-square310x310logo"/></meta></link></link></meta></link></link></link></link></link></link></link></link></link></link></link></link></link></head><body class="elnortedecastilla"><!-- GTM --><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MJKFH6" style="display:none;visibility:hidden" width="0"></iframe></noscript><!-- End GTM --><noscript><img border="0" height="1" src="//sadbmetrics.elnortedecastilla.com/b/ss/vocelnortedecastilla,voces/1/G.4--NS/123456789?pageName=&amp;g=/js-noactive&amp;v55=elnortedecastilla&amp;c56=elnortedecastilla" width="1"/></noscript><noscript><p><img alt="*" height="1" src="//b.scorecardresearch.com/p?c1=2&amp;c2=7715761&amp;ns_site=elnortedecastilla&amp;name=hemeroteca.portadilla&amp;voc_site=elnortedecastilla&amp;voc_se=hemeroteca&amp;voc_s1=&amp;voc_s2=&amp;voc_s3=&amp;voc_s4=&amp;voc_tn=portadilla&amp;voc_ho=0&amp;voc_tc=hemeroteca&amp;voc_ed=&amp;voc_au=&amp;voc_fep=&amp;voc_fem=&amp;voc_or=&amp;voc_pr=1&amp;voc_pl=contenido-web&amp;voc_pu=methode&amp;voc_usrid=&amp;voc_tusr=anonimo&amp;voc_ate=&amp;voc_idi=es&amp;voc_usrag=&amp ...
#                                     60+ Activos (14)
#                                 </option><option data-id="castillayleon" value="castillayleon">
#                                     Castilla y León (4)
#                                 </option><option data-id="culturas" value="culturas">
#                                     Culturas (6)
#                                 </option><option data-id="degustacastillayleon" value="degustacastillayleon">
#                                     Degusta Castilla y León (2)
#                                 </option><option data-id="deportes" value="deportes">
#                                     Deportes (3)
#                                 </option><option data-id="sociedad" value="sociedad">
#                                     Sociedad (1)
#                                 </option><option data-id="va-de-moda" value="va-de-moda">
#                                     Va de Moda (1)
#                                 </option><option data-id="valladolid" value="valladolid">
#                                     Valladolid (175)
#                                 </option></select><i class="voc-icons downArrow"></i></div></div><div class="col-md-2"><div class="voc-styled-select"><select class="voc-filter-select" data-voc-dependent-select="selectSeccion" data-voc-krammer-filter-subsection="" id="selectSubseccion" name="subsection[]"><option disabled="disabled" selected="">Subsección</option><option data-id="culturas" value="culturas/musica">
#                                     Música (1)
#                                 </option><option data-id="culturas" value="culturas/seminci">
#                                     Seminci (2)
#                                 </option><option data-id="culturas" value="culturas/teatrodecalle">
#                                     Teatro de Calle (2)
#                                 </option><option data-id="degustacastillayleon" value="degustacastillayleon/escapadas-emociones">
#                                     Escapadas y Emociones (2)
#                                 </option><option data-id="deportes" value="deportes/correconelnorte">
#                                     Corre con el Norte (2)
#                                 </option><option data-id="deportes" value="deportes/rugby">
#                                     Rugby (1)
#                                 </option><option data-id="valladolid" value="valladolid/fiestas">
#                                     Fiestas (9)
#                                 </option><option data-id="valladolid" value="valladolid/fiestas/caseta">
#                                     Fiestas/Caseta (3)
#                                 </option><option data-id="valladolid" value="valladolid/fiestas/programa">
#                                     Fiestas/Programa (5)
#                                 </option></select><i class="voc-icons downArrow"></i></div></div><div class="col-md-2"><div class="voc-styled-select"><select class="voc-filter-select" data-voc-krammer-filter-author="" id="selectAutor" name="author[]"><option disabled="disabled" selected="selected">Autor</option><option value="alvaro-gomez">Álvaro Gómez</option><option value="angel-blanco-escalona">Ángel Blanco Escalona</option><option value="antonio-g-encinas">Antonio G. Encinas</option><option value="el-norte">El Norte</option><option value="eva-esteban">Eva Esteban</option><option value="j-a-pardal">J. A. Pardal</option><option value="j-asua">J. Asua</option><option value="j-sanz">J. Sanz</option><option value="jesus-dominguez">Jesús Domínguez</option><option value="jorge-moreno">Jorge Moreno</option><option value="l-m-c">L. M. C.</option><option value="laura-cembranos">LAURA CEMBRANOS</option><option value="laura-negro">Laura Negro</option><option value="lorena-sancho">Lorena Sancho</option><option value="lorena-sancho-yuste">Lorena Sancho Yuste</option><option value="luis-miguel-de-pablos">Luis Miguel de Pablos</option><option value="m-e-g">M. E. G.</option><option value="m-j-pascual">M. J. Pascual</option><option value="victor-borda">Víctor Borda</option><option value="victor-vela">Víctor Vela</option></select><i class="voc-icons downArrow"></i></div></div><div class="form-group col-md-2"><label for="dd">Desde</label><input class="voc-form-control voc-hemeroteca-filter" data-voc-krammer-filter-date-start="" placeholder="dd-mm-aaaa" type="text" value=""/></div><div class="form-group col-md-2"><label for="dd">Hasta</label><input class="voc-form-control voc-hemeroteca-filter" data-voc-krammer-filter-date-end="" placeholder="dd-mm-aaaa" type="text" value=""/></div></div><div class="form-buscador btn-buscador"><div class="input-group"><input class="voc-form-control voc-filter-btn" data-voc-krammer-filter-submit="" id="search" type="submit" value="Filtrar"/></div></div></form><span class="voc-filter-title">Formato</span><div class="hemeroteca-filter-list row"><a href="            /hemeroteca/noticia/aquavall.html?order=-fecha
#     "><div class="col-md-2 col-sm-2 col-xs-6"><div class="hemeroteca-filter">
#                                 Noticias
#                             </div><div class="hemeroteca-number">202</div></div></a></div><div class="format-container row"></div></div></div><div class="row voc-hemeroteca-subsections"><span class="voc-active type">Noticias</span><span class="voc-count">
#                                                                                             1-10 de 202 noticias
#                     </span><span class="pull-right orderby">
#                         Ordenar por:
#                         <a class="order" href="/hemeroteca/aquavall.html">Relevancia</a><a class="order active" href="/hemeroteca/aquavall.html?order=-fecha">Últimos</a><a class="order" href="/hemeroteca/aquavall.html?order=%2Bfecha">Antiguos</a></span></div><nav class="voc-hemeroteca-subnavigation"><span class="voc-desta">Temas</span></nav><div class="row voc-container-flex"><div class="col-md-8 col-sm-12"><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">09-09-2020 <span>13:50</span></time><span class="voc-new-section">Valladolid/Fiestas</span><h2 class="voc-title"><a alt="Mensajes de apoyo a los vallisoletanos" href="https://www.elnortedecastilla.es/valladolid/fiestas/mensajes-apoyo-vallisoletanos-20200908183139-nt.html" title="Mensajes de apoyo a los vallisoletanos">
#                 Mensajes de apoyo a los vallisoletanos
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/fiestas/mensajes-apoyo-vallisoletanos-20200908183139-nt.html"><img alt="Mensajes de apoyo a los vallisoletanos" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202009/08/media/cortadas/portada-apoyos-kyKD--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="Mensajes de apoyo a los vallisoletanos" src="https://static.elnortedecastilla.es/www/multimedia/202009/08/media/cortadas/portada-apoyos-kyKD--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">20-08-2020 <span>12:15</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid" href="https://www.elnortedecastilla.es/valladolid/aquavall-rehabilita-tecnologia-20200820121334-nt.html" title="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid">
#                 Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/aquavall-rehabilita-tecnologia-20200820121334-nt.html"><img alt="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202008/20/media/cortadas/sss-k0GB--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid" src="https://static.elnortedecastilla.es/www/multimedia/202008/20/media/cortadas/sss-k0GB--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">05-08-2020 <span>18:50</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid" href="https://www.elnortedecastilla.es/valladolid/operarios-trabajan-reparar-20200805105125-nt.html" title="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid">
#                 El reventón de una tubería obliga a cortar la calle Olmo de Valladolid
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/operarios-trabajan-reparar-20200805105125-nt.html"><img alt="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202008/05/media/cortadas/reventon-kPxG--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid" src="https://static.elnortedecastilla.es/www/multimedia/202008/05/media/cortadas/reventon-kPxG--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">26-07-2020 <span>21:09</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus" href="https://www.elnortedecastilla.es/valladolid/valladolid-analiza-domingos-20200726142437-nt.html" title="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus">
#                 Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/valladolid-analiza-domingos-20200726142437-nt.html"><img alt="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202007/26/media/cortadas/1426358321-k14D--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus" src="https://static.elnortedecastilla.es/www/multimedia/202007/26/media/cortadas/1426358321-k14D--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">08-07-2020 <span>19:14</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="Los vallisoletanos podrán pagar los impuestos municipales en Correos" href="https://www.elnortedecastilla.es/valladolid/vallisoletanos-podran-pagar-20200708190541-nt.html" title="Los vallisoletanos podrán pagar los impuestos municipales en Correos">
#                 Los vallisoletanos podrán pagar los impuestos municipales en Correos
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/vallisoletanos-podran-pagar-20200708190541-nt.html"><img alt="Los vallisoletanos podrán pagar los impuestos municipales en Correos" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202007/08/media/cortadas/1425965920-kt7B--228x141@El%20Norte.JPG" loading="lazy"/><noscript><img alt="Los vallisoletanos podrán pagar los impuestos municipales en Correos" src="https://static.elnortedecastilla.es/www/multimedia/202007/08/media/cortadas/1425965920-kt7B--228x141@El%20Norte.JPG"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">05-07-2020 <span>17:01</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados" href="https://www.elnortedecastilla.es/valladolid/ayuntamiento-disena-plan-20200705165706-nt.html" title="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados">
#                 El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/ayuntamiento-disena-plan-20200705165706-nt.html"><img alt="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202007/05/media/cortadas/NF0MDQC1-kBfC--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados" src="https://static.elnortedecastilla.es/www/multimedia/202007/05/media/cortadas/NF0MDQC1-kBfC--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">05-07-2020 <span>02:49</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid" href="https://www.elnortedecastilla.es/valladolid/reventon-anega-locales-20200704171009-nt.html" title="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid">
#                 Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/reventon-anega-locales-20200704171009-nt.html"><img alt="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202007/04/media/cortadas/Rondi6-kGhH--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid" src="https://static.elnortedecastilla.es/www/multimedia/202007/04/media/cortadas/Rondi6-kGhH--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">03-07-2020 <span>23:42</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares" href="https://www.elnortedecastilla.es/valladolid/reventon-tuberia-rondilla-20200703232817-nt.html" title="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares">
#                 El reventón de una tubería en la Rondilla anega varios locales de la calle Linares
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/reventon-tuberia-rondilla-20200703232817-nt.html"><img alt="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202007/03/media/cortadas/averia1-k2eC--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares" src="https://static.elnortedecastilla.es/www/multimedia/202007/03/media/cortadas/averia1-k2eC--228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">03-07-2020 <span>14:07</span></time><span class="voc-new-section">Valladolid</span><h2 class="voc-title"><a alt="Los parques infantiles de Valladolid reabrirán el martes" href="https://www.elnortedecastilla.es/valladolid/parques-infantiles-valladolid-20200703135735-nt.html" title="Los parques infantiles de Valladolid reabrirán el martes">
#                 Los parques infantiles de Valladolid reabrirán el martes
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/valladolid/parques-infantiles-valladolid-20200703135735-nt.html"><img alt="Los parques infantiles de Valladolid reabrirán el martes" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202007/03/media/cortadas/parque%20infantil-k0ID-U110692733585KqH-228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="Los parques infantiles de Valladolid reabrirán el martes" src="https://static.elnortedecastilla.es/www/multimedia/202007/03/media/cortadas/parque%20infantil-k0ID-U110692733585KqH-228x141@El%20Norte.jpg"/></noscript></a></picture></article><article class="voc-topics-page voc-hemeroteca-page voc-photo-news"><div><time class="voc-date">22-06-2020 <span>17:45</span></time><span class="voc-new-section">Degusta Castilla y León/Escapadas y Emociones</span><h2 class="voc-title"><a alt="Promueve el consumo de agua del grifo entre los hosteleros" href="https://www.elnortedecastilla.es/degustacastillayleon/escapadas-emociones/promueve-consumo-agua-20200622190614-nt.html" title="Promueve el consumo de agua del grifo entre los hosteleros">
#                 Promueve el consumo de agua del grifo entre los hosteleros
#             </a></h2></div><picture><a class="voc-horizontal voc-img-icon-link" href="https://www.elnortedecastilla.es/degustacastillayleon/escapadas-emociones/promueve-consumo-agua-20200622190614-nt.html"><img alt="Promueve el consumo de agua del grifo entre los hosteleros" class="lazy" data-original="https://static.elnortedecastilla.es/www/multimedia/202006/22/media/cortadas/fotoaquavallok-kK2H--228x141@El%20Norte.jpg" loading="lazy"/><noscript><img alt="Promueve el consumo de agua del grifo entre los hosteleros" src="https://static.elnortedecastilla.es/www/multimedia/202006/22/media/cortadas/fotoaquavallok-kK2H--228x141@El%20Norte.jpg"/></noscript></a></picture></article><div class="pagination-wrapper"><nav><ul class="voc-pagination list-inline"><li class="active"><a href="?pag=1&amp;order=-fecha">1</a></li>
#                                     <li><a href="?pag=2&amp;order=-fecha">2</a></li>
#                                     <li><a href="?pag=3&amp;order=-fecha">3</a></li>
#                                     <li><a href="?pag=4&amp;order=-fecha">4</a></li>
#                                     <li><a href="?pag=5&amp;order=-fecha">5</a></li>
#                                                     <li><a href="?pag=2&amp;order=-fecha"><i class="voc-icons rightArrow"></i></a></li>
#                     <li><a href="?pag=21&amp;order=-fecha"><i class="voc-icons rightArrow"></i><i class="voc-icons rightArrow"></i></a></li>
#                             </ul></nav></div></div><div class="col-md-4 col-sm-12 col-xs-12 voc-flex"><div class="voc-most-wrapper voc-most-wrapper--large-margins voc-most-readed--with-tabs voc-detail"><section class="voc-most-readed" style=""><header><h3><a href="https://www.elnortedecastilla.es/top-noticias/mas-vistos.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=">Lo <span class="voc-icon-plus">+</span> leído</a></h3><a class="voc-top" href="https://www.elnortedecastilla.es/top-noticias/mas-vistos.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=" title="Top 50">Top 50</a></header><div class="tab-content"><div id="most-readed-section"><ul><li><h4><a href="https://www.elnortedecastilla.es/castillayleon/coronavirus-acelera-castilla-20201006131030-nt.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=" title="El coronavirus acelera en Castilla y León con 660 nuevos casos y 16 defunciones"><span class="voc-number" style="width: auto; height: auto; background: none;">1</span>
#                                     El coronavirus acelera en Castilla y León con 660 nuevos casos y 16 defunciones
#                                 </a></h4></li><li><h4><a href="https://www.elnortedecastilla.es/realvalladolid/real-valladolid-ficha-20201005170436-nt.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=" title="El Real Valladolid se refuerza con Jota y Roque Mesa, y da salida a Moyano"><span class="voc-number" style="width: auto; height: auto; background: none;">2</span>
#                                     El Real Valladolid se refuerza con Jota y Roque Mesa, y da salida a Moyano
#                                 </a></h4></li><li><h4><a href="https://www.elnortedecastilla.es/valladolid/clinico-abre-nuevas-20201006210608-nt.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=" title="El Clínico de Valladolid abre sus nuevas 10 camas de UCI, que aliviarán su saturación"><span class="voc-number" style="width: auto; height: auto; background: none;">3</span>
#                                     El Clínico de Valladolid abre sus nuevas 10 camas de UCI, que aliviarán su saturación
#                                 </a></h4></li><li><h4><a href="https://www.elnortedecastilla.es/valladolid/provincia/localizan-semanas-despues-20201005143144-nt.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=" title="Localizan, dos semanas después, a la menor desaparecida en Arroyo de la Encomienda"><span class="voc-number" style="width: auto; height: auto; background: none;">4</span>
#                                     Localizan, dos semanas después, a la menor desaparecida en Arroyo de la Encomienda
#                                 </a></h4></li><li><h4><a href="https://www.elnortedecastilla.es/castillayleon/sanidad-devuelve-atencion-20201006144851-nt.html#vca=modulos&amp;vso=elnortedecastilla&amp;vmc=lo-mas-leido&amp;vli=" title="Sanidad devuelve la atención presencial a los consultorios de la región solo con cita previa"><span class="voc-number" style="width: auto; height: auto; background: none;">5</span>
#                                     Sanidad devuelve la atención presencial a los consultorios de la región solo con cita previa
#                                 </a></h4></li></ul></div></div></section></div><div class="voc-advertising voc-adver-aside-detail voc-adver-displacement"><div class="voc-w300 voc-msauto" style="position: relative;"><div class="voc-w300 voc-h600 voc-mb24 voc-msauto" data-voc-adver-displacement="" id="robapaginas_dos_local"><div data-voc-vam="" data-voc-vam-outofpage="false" data-voc-vam-position="robapaginas_dos_local"></div></div></div></div></div></div></div></div><div class="voc-advertising voc-adver-prefooter"><div class="voc-w980 voc-mt4 voc-mb32 voc-msauto" id="megabanner_local"><div data-voc-vam="" data-voc-vam-outofpage="false" data-voc-vam-position="megabanner_local"></div></div></div></div><footer><div class="voc-footer-coorp col-xs-12 col-sm-12 col-md-4 col-lg-4"><div class="voc-footer-logo voc-elnortedecastilla"><a href="https://www.elnortedecastilla.es">ELNORTEDECASTILLA.ES.</a></div><div class="voc-copyadd"><span class="voc-copy">© EL NORTE DE CASTILLA</span><address>Calle Vázquez de Menchaca, 10, 47008 - Valladolid</address></div><ul class="voc-social list-inline"><li><a class="voc-facebook" href="https://www.facebook.com/nortecastilla" target="_blank" title="facebook"><i class="voc-icons facebook"></i></a></li><li><a class="voc-twitter" href="https://twitter.com/nortecastilla" target="_blank" title="twitter"><i class="voc-icons twitter"></i></a></li><li><a class="voc-whatsapp" href="https://www.elnortedecastilla.es/castillayleon/envianos-fotos-videos-20170607210653-nt.html" target="_blank" title="whatsapp"><i class="voc-icons whatsapp"></i></a></li><li><a class="voc-instagram" href="https://www.instagram.com/elnortedecastilla/" target="_blank" title="instagram"><i class="voc-icons instagram"></i></a></li></ul></div><div class="voc-media col-xs-12 col-sm-12 col-md-8 col-lg-8"><div class="voc-footer-logo-blue"><a href="https://www.vocento.com/" target="_blank" title="Vocento">Vocento</a><i class="voc-icons downArrow navbar-toggle" data-target="#media" data-toggle="collapse"></i></div><ul class="navbar-collapse collapse" id="media"><li><a href="https://www.abc.es/" target="_blank" title="ABC">ABC</a></li><li><a href="https://sevilla.abc.es/" target="_blank" title="ABC Sevilla">ABC Sevilla</a></li><li><a href="https://www.hoy.es/" target="_blank" title="Hoy">Hoy</a></li><li><a href="https://www.elcorreo.com/" target="_blank" title="El Correo">El Correo</a></li><li><a href="https://www.larioja.com/" target="_blank" title="La Rioja">La Rioja</a></li><li><a href="https://www.elnortedecastilla.es/" target="_blank" title="El Norte de Castilla">El Norte de Castilla</a></li><li><a href="https://www.diariovasco.com/" target="_blank" title="Diario Vasco">Diario Vasco</a></li><li><a href="https://www.elcomercio.es/" target="_blank" title="El Comercio">El Comercio</a></li><li><a href="https://www.ideal.es/" target="_blank" title="Ideal">Ideal</a></li><li><a href="https://www.diariosur.es/" target="_blank" title="Sur">Sur</a></li><li><a href="https://www.lasprovincias.es/" target="_blank" title="Las Provincias">Las Provincias</a></li><li><a href="https://www.eldiariomontanes.es/" target="_blank" title="El Diario Montañés">El Diario Montañés</a></li><li><a href="https://www.lavozdigital.es/" target="_blank" title="La Voz Digital">La Voz Digital</a></li><li><a href="https://www.laverdad.es/" target="_blank" title="La Verdad">La Verdad</a></li><li><a href="https://www.leonoticias.com/" target="_blank" title="Leonoticias.com">Leonoticias</a></li><li><a href="https://www.burgosconecta.es/" target="_blank" title="Burgosconecta">Burgosconecta</a></li><li><a href="https://www.pisocompartido.com/" target="_blank" title="Piso Compartido">Piso Compartido</a></li><li><a href="https://www.infoempleo.com/" target="_blank" title="Infoempleo">Infoempleo</a></li><li><a href="http://www.finanzas.com/" target="_blank" title="Finanzas">Finanzas</a></li><li><a href="https://www.autocasion.com/" target="_blank" title="Autocasión">Autocasión</a></li> ...
#                 privacidad</a></li><li><a href="https://www.elnortedecastilla.es/publicidad.html" target="blank" title="Publicidad">Publicidad</a></li><li><a href="https://www.elnortedecastilla.es/mapa-web.html" title="Mapa web">Mapa web</a></li><li><a onclick="Voonto.cmp.show();" style="cursor:pointer;" title="Política de cookies">Política de cookies</a></li></ul><ev-paywall-notifier group-name="elnortedecastilla"></ev-paywall-notifier></footer><nav class="voc-main-menu voc-main-menu-onplus"><!-- arrow close--><button class="voc-close-burguer-mobile-onplus" type="button"><i class="voc-icons close-x"></i></button><!-- end --><div class="container-menu-onplus2"><div class="login-user-new" data-voc-username-hamburguer=""><a class="name-user-new" href="https://areapersonal.elnortedecastilla.es/suscripcion/">Suscríbete</a></div><form action="/hemeroteca/" class="voc-search-menu hidden-md hidden-lg hidden-sm" data-voc-krammer-term="" method="get"><button><i class="voc-icons search"></i></button><input data-voc-krammer-term-all-words="" placeholder="Buscar..." required="" type="search"/></form></div><input checked="" class="voc-select-menu-sections" id="sectionsMenu" name="selectMenuMobile" type="radio"/><label class="voc-select-menu hidden-md hidden-lg hidden-sm" for="sectionsMenu"><span>Secciones</span></label><input class="voc-select-menu-services" id="servicesMenu" name="selectMenuMobile" type="radio"/><label class="voc-select-menu hidden-md hidden-lg hidden-sm" for="servicesMenu"><span>Servicios</span></label><div class="voc-content-menu"><ul class="voc-menu-level-1st voc-menu-sections"><li><h3><a href="/" target="_self" title="El Norte de Castilla">Portada</a></h3><div class="onplus-home-burguer"><i class="voc-icons-home-burguer"></i></div></li><li><h3><a href="/valladolid/" target="_self" title="Noticias de Valladolid">Valladolid</a><i class="voc-icons downArrow" data-target="#linkmainsubmenu02" data-toggle="collapse"></i></h3><hgroup class="collapse" id="linkmainsubmenu02"><h4><a href="/temas/lugares/valladolid-ciudad.html" target="_self" title="Noticias de la ciudad de Valladolid">Valladolid       ciudad</a></h4><h4><a href="/valladolid/provincia/" target="_self" title="Noticias de la provincia de Valladolid">Provincia</a></h4><h4><a href="https://especial.elnortedecastilla.es/pueblos/" target="_self" title="Busca tu pueblo">Busca tu pueblo</a></h4><h4><a href="/temas/generales/sucesos-en-valladolid.html" target="_self" title="Sucesos en Valladolid">Sucesos en Valladolid</a></h4><h4><a href="https://soydearroyo.elnortedecastilla.es" target="_self" title="Soy de Arroyo">Soy de Arroyo</a></h4></hgroup></li><li><h3><a href="/palencia/" target="_self" title="Noticias de Palencia">Palencia</a></h3></li><li><h3><a href="/segovia/" target="_self" title="Noticias de Segovia">Segovia</a></h3></li><li><h3><a href="/salamanca/" target="_self" title="Noticias de Salamanca">Salamanca</a></h3></li><li><h3><a href="/castillayleon/" target="_self" title="Noticias de Castilla y León">Castilla y León</a><i class="voc-icons downArrow" data-target="#linkmainsubmenu06" data-toggle="collapse"></i></h3><hgroup class="collapse" id="linkmainsubmenu06"><h4><a href="/avila/" target="_self" title="Noticias de Ávila">Ávila</a></h4><h4><a href="/burgos/" target="_self" title="Noticias de Burgos">Burgos</a></h4><h4><a href="/leon/" target="_self" title="Noticias de León">León</a></h4><h4><a href="/soria/" target="_self" title="Noticias de Soria">Soria</a></h4><h4><a href="/zamora/" target="_self" title="Noticias de Zamora">Zamora</a></h4><h4><a href="/temas/generales/campo.html" target="_self" title="Noticias del campo">Campo</a></h4><h4><a href="/temas/generales/educacion.html" target="_self" title="Noticias de educación">Educación</a></h4></hgroup></li><li><h3><a href="https://www.elnortedecastilla.es/temas/generales/coronavirus.html" target="_self" title="Crisis del coronavirus">Crisis del coronavirus</a><i class="voc-icons downArrow" data-target="#li ...
#   Voonto.ready.then(function (app) {
#     app.load('//static.elnortedecastilla.es/squido/6.0.14/squido.js');    app.load('//cabeceras.vocento.com/vocuser/v4/resources/js/ppll/loader/vocento-vocuser-preloader.js?v=202010060813');
#     app.load('//static.vocento.com/paywall/1.4.2/paywall.js');    app.load('//static.vocento.com/video-player/1.3.2/video-player.js');
#     app.load('//static.vocento.com/alerts/3.2.2/alerts.js');    app.load('//static.vocento.com/starred/1.0.10/starred.js');
#     app.load('//static.vocento.com/sportsdata/1.1.20/sportsdata.js');
#     app.load('//static.vocento.com/krammer/1.2.3/krammer.js');
#     app.load('//static1.elnortedecastilla.es/frontal/2.11.9/frontal-libraries.js');
#     app.load('//static.vocento.com/widgets/1.10.0/loader.js');    app.load('https://static.vocento.com/freezone-newsletter-subscriber/1.9.0/freezone-widget.js');
#
#     app.when('vocuser:gigyaready').then(function () {
#       app.load('//static.vocento.com/comments/3.2.1/comments.js');
#     });
#
#     window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#       if (!document.getElementById(i)){
#         e.async = 1;
#         e.src = u;
#         e.id = i;
#         f.parentNode.insertBefore(e, f);
#       }
#     }(document.createElement('script'),
#       document.getElementsByTagName('script')[0],
#       '//cdn.taboola.com/libtrc/vocentoregionales-network/loader.js',
#       'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#     {window.performance.mark('tbl_ic');}
#     app.load('//static.vocento.com/prospect/2.3.0/prospect.js');
#             app.when('consent:dmp').then(function(result) {
#       if (result) {
#         setTimeout(function() {app.load('//js.agkn.com/prod/v0/tag.js');}, 2000);
#       }
#     })
#   });
# </script><script type="text/javascript">
#   window._taboola = window._taboola || [];
#   _taboola.push({flush: true});
# </script><script>function setUpAgknTag(tag) {tag.setBpId("vocento");}</script><div class="voc-cookie-message voc-cookie-message--hidden animated" data-voc-cookies-advice=""><div class="voc-cookie-message__container"><span class="voc-cookie-message__notice">
#       Utilizamos “cookies” propias y de terceros para elaborar información estadística y mostrarle publicidad, contenidos y servicios personalizados a través del análisis de su navegación. Si continúa navegando acepta su uso. <a href="https://www.vocento.com/politica-cookies/" target="_blank" title="Si desea más información pinche aquí">Más información y cambio de configuración.</a></span><button class="voc-cookie-message__button" data-voc-cookies-advice-close="" type="button">Aceptar</button></div></div><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"c72ce647f9","applicationID":"295625140","transactionName":"NFwBY0dZDEtZW0dcDQ0WIlRBUQ1WF15BWgwXWA8ZYwlMWUpbW1wUBkpNRFBZEFtQFkdQGhc=","queueTime":0,"applicationTime":428,"atts":"GBsWFQ9DHxQaWREPGR5E","errorBeacon":"bam.nr-data.net","agent":""}</script></body></html>

# %% [markdown]
# ### Preparación del contenido HTML para su análisis

# %%
# El texto HTML almacenado contiene todo el texto de la página, con muchas secciones irrelevantes para el análisis
# El análisis de sentimientos se centrará solamente en los titulares recuperados de la hemeroteca

# En este ejemplo, se usa la cabecera de tipo 'h2' para maquetar la lista de titulares de noticias
# por tanto seleccionaremos solo las partes de código HTML que son cabeceras 'h2'
# Esto puede variar si se analiza una pagina diferente, con una maquetación distinta
news_general = page_soup.findAll('h2')

print(news_general)
# Out:
# [<h2 class="voc-hemeroteca-title-inside"><strong>Resultados</strong> para <span class="topic">'aquavall'</span></h2>, <h2 class="voc-title"><a alt="Mensajes de apoyo a los vallisoletanos" href="https://www.elnortedecastilla.es/valladolid/fiestas/mensajes-apoyo-vallisoletanos-20200908183139-nt.html" title="Mensajes de apoyo a los vallisoletanos">
#                 Mensajes de apoyo a los vallisoletanos
#             </a></h2>, <h2 class="voc-title"><a alt="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid" href="https://www.elnortedecastilla.es/valladolid/aquavall-rehabilita-tecnologia-20200820121334-nt.html" title="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid">
#                 Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid
#             </a></h2>, <h2 class="voc-title"><a alt="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid" href="https://www.elnortedecastilla.es/valladolid/operarios-trabajan-reparar-20200805105125-nt.html" title="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid">
#                 El reventón de una tubería obliga a cortar la calle Olmo de Valladolid
#             </a></h2>, <h2 class="voc-title"><a alt="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus" href="https://www.elnortedecastilla.es/valladolid/valladolid-analiza-domingos-20200726142437-nt.html" title="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus">
#                 Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus
#             </a></h2>, <h2 class="voc-title"><a alt="Los vallisoletanos podrán pagar los impuestos municipales en Correos" href="https://www.elnortedecastilla.es/valladolid/vallisoletanos-podran-pagar-20200708190541-nt.html" title="Los vallisoletanos podrán pagar los impuestos municipales en Correos">
#                 Los vallisoletanos podrán pagar los impuestos municipales en Correos
#             </a></h2>, <h2 class="voc-title"><a alt="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados" href="https://www.elnortedecastilla.es/valladolid/ayuntamiento-disena-plan-20200705165706-nt.html" title="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados">
#                 El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados
#             </a></h2>, <h2 class="voc-title"><a alt="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid" href="https://www.elnortedecastilla.es/valladolid/reventon-anega-locales-20200704171009-nt.html" title="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid">
#                 Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid
#             </a></h2>, <h2 class="voc-title"><a alt="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares" href="https://www.elnortedecastilla.es/valladolid/reventon-tuberia-rondilla-20200703232817-nt.html" title="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares">
#                 El reventón de una tubería en la Rondilla anega varios locales de la calle Linares
#             </a></h2>, <h2 class="voc-title"><a alt="Los parques infantiles de Valladolid reabrirán el martes" href="https://www.elnortedecastilla.es/valladolid/parques-infantiles-valladolid-20200703135735-nt.html" title="Los parques infantiles de Valladolid reabrirán el martes">
#                 Los parques infantiles de Valladolid reabrirán el martes
#             </a></h2>, <h2 class="voc-title"><a alt="Promueve el consumo de agua del grifo entre los hosteleros" href="https://www.elnortedecastilla.es/degustacastillayleon/escapadas-emociones/promueve-consumo-agua-20200622190614-nt.html" title="Promueve el consumo de agua del grifo entre los hosteleros">
#                 Promueve el consumo de agua del grifo entre los hosteleros
#             </a></h2>]

# %%
# Los titulares de las noticias que muestra una consulta a la hemeroteca continenen enlaces a ellas
# En HTML los hipervínculos se indican con el marcador <a....></a>
# Como el objeto soup mantienen la estructura de la página, podemos extraerlos con ese marcador HTML

# Creamos un objeto de texto para el contenido
news_data = []

for news in news_general:
    news1 = news.find('a')
    news_data.append([news1])

print(news_data)
# Out:
# [[None], [<a alt="Mensajes de apoyo a los vallisoletanos" href="https://www.elnortedecastilla.es/valladolid/fiestas/mensajes-apoyo-vallisoletanos-20200908183139-nt.html" title="Mensajes de apoyo a los vallisoletanos">
#                 Mensajes de apoyo a los vallisoletanos
#             </a>], [<a alt="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid" href="https://www.elnortedecastilla.es/valladolid/aquavall-rehabilita-tecnologia-20200820121334-nt.html" title="Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid">
#                 Aquavall rehabilita con tecnología sin zanja la red de alcantarillado de Valladolid
#             </a>], [<a alt="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid" href="https://www.elnortedecastilla.es/valladolid/operarios-trabajan-reparar-20200805105125-nt.html" title="El reventón de una tubería obliga a cortar la calle Olmo de Valladolid">
#                 El reventón de una tubería obliga a cortar la calle Olmo de Valladolid
#             </a>], [<a alt="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus" href="https://www.elnortedecastilla.es/valladolid/valladolid-analiza-domingos-20200726142437-nt.html" title="Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus">
#                 Valladolid analiza todos los domingos sus aguas residuales para buscar trazas de coronavirus
#             </a>], [<a alt="Los vallisoletanos podrán pagar los impuestos municipales en Correos" href="https://www.elnortedecastilla.es/valladolid/vallisoletanos-podran-pagar-20200708190541-nt.html" title="Los vallisoletanos podrán pagar los impuestos municipales en Correos">
#                 Los vallisoletanos podrán pagar los impuestos municipales en Correos
#             </a>], [<a alt="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados" href="https://www.elnortedecastilla.es/valladolid/ayuntamiento-disena-plan-20200705165706-nt.html" title="El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados">
#                 El Ayuntamiento diseña un plan para «prevenir y erradicar» el acoso laboral entre sus empleados
#             </a>], [<a alt="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid" href="https://www.elnortedecastilla.es/valladolid/reventon-anega-locales-20200704171009-nt.html" title="Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid">
#                 Un reventón anega dos locales y deja 15 horas sin agua dos calles de La Rondilla en Valladolid
#             </a>], [<a alt="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares" href="https://www.elnortedecastilla.es/valladolid/reventon-tuberia-rondilla-20200703232817-nt.html" title="El reventón de una tubería en la Rondilla anega varios locales de la calle Linares">
#                 El reventón de una tubería en la Rondilla anega varios locales de la calle Linares
#             </a>], [<a alt="Los parques infantiles de Valladolid reabrirán el martes" href="https://www.elnortedecastilla.es/valladolid/parques-infantiles-valladolid-20200703135735-nt.html" title="Los parques infantiles de Valladolid reabrirán el martes">
#                 Los parques infantiles de Valladolid reabrirán el martes
#             </a>], [<a alt="Promueve el consumo de agua del grifo entre los hosteleros" href="https://www.elnortedecastilla.es/degustacastillayleon/escapadas-emociones/promueve-consumo-agua-20200622190614-nt.html" title="Promueve el consumo de agua del grifo entre los hosteleros">
#                 Promueve el consumo de agua del grifo entre los hosteleros
#             </a>]]

# %% [markdown]
# ### Extracción de palabras relevantes desde los titulares de noticias

# %%
# Para facilitar el análisis limpiaremos el texto, simplificándolo y eliminando signos de puntuacion
# Además, para reducir las variaciones, ponemos todas las letras en minusculas

# En primer lugar definimos un modelo que obvie los signos de puntuación usados en el lenguaje natural
# Usamos la libreria de expresiones regulares re. Usaremos esta funcion más adelante dentro del bucle
# Añado algunos caracteres que no contempla la librería
regex = re.compile('[%s]' % re.escape((string.punctuation) + u'¡' + u'¿' + u'«'+ u'»'))


# Creamos un objeto lista vacío para poner todas las palabras extraidas
data_new = []

# Recorremos la selección con las cabeceras de noticias para extraer las palabras
# Recorremos de una en una las lineas, seleccionando las que no sean nulas
for new in news_data:
    if not 'None' in new:
        for sentence in new:
            if sentence is None:
                pass
            else:
                # Si la línea no es nula, partimos su contenido en palabras
                for words in sentence:
                    words = words.split()
                    # Una vez extraidas las palabras, las procesamos
                    for word in words:
                        # Ponemos todos los caracteres de cada palabra en minúsculas
                        token = word.lower()
                        # Eliminamos los signos de puntuacion sustituyéndolos (sub) por nada
                        new_token1 = regex.sub(u'', token)
                        # Incorporamos esa palabra al objeto lista que creamos inicialmente
                        data_new.append(new_token1)

# %%
# El contenido del objeto lista con las palabras que contienen los titulares de noticias es
print(data_new)
# Out:
# ['mensajes', 'de', 'apoyo', 'a', 'los', 'vallisoletanos', 'aquavall', 'rehabilita', 'con', 'tecnología', 'sin', 'zanja', 'la', 'red', 'de', 'alcantarillado', 'de', 'valladolid', 'el', 'reventón', 'de', 'una', 'tubería', 'obliga', 'a', 'cortar', 'la', 'calle', 'olmo', 'de', 'valladolid', 'valladolid', 'analiza', 'todos', 'los', 'domingos', 'sus', 'aguas', 'residuales', 'para', 'buscar', 'trazas', 'de', 'coronavirus', 'los', 'vallisoletanos', 'podrán', 'pagar', 'los', 'impuestos', 'municipales', 'en', 'correos', 'el', 'ayuntamiento', 'diseña', 'un', 'plan', 'para', 'prevenir', 'y', 'erradicar', 'el', 'acoso', 'laboral', 'entre', 'sus', 'empleados', 'un', 'reventón', 'anega', 'dos', 'locales', 'y', 'deja', '15', 'horas', 'sin', 'agua', 'dos', 'calles', 'de', 'la', 'rondilla', 'en', 'valladolid', 'el', 'reventón', 'de', 'una', 'tubería', 'en', 'la', 'rondilla', 'anega', 'varios', 'locales', 'de', 'la', 'calle', 'linares', 'los', 'parques', 'infantiles', 'de', 'valladolid', 'reabrirán', 'el', 'martes', 'promueve', 'el', 'consumo', 'de', 'agua', 'del', 'grifo', 'entre', 'los', 'hosteleros']

# %%
# Deseamos solo las palabras relevantes, las que determinan el sentido y sentimientos de sus frases

# Los pronombres, artículos o preposiciones no son relevantes para determinar el sentimiento
# Podemos extraer las palabras relevantes del lenguaje natural mediante la librería NLTK

# Descargo las stopwords actualizadas de la libreria NLTK
nltk.download('stopwords') # Descargo su lista de palabras irrelevantes (stopwords)

# Selecciono solo las palabras irrelevantes (stopwords) del idioma español
stop_words = set(stopwords.words('spanish'))

# Añado algunas palabras que en mi caso particular no serán relevantes
stop_words.update(('valladolid', 'vallisoletano', 'aquavall', 'agua', 'aguas'))

# Creo un objeto lista de palabras relevantes
data_no_stopwords = []

# Recorro la lista de palabras extraidas anteriormente de los titulaes para dejar solo las relevantes
for word in data_new:
    if not word in stop_words:
        data_no_stopwords.append(word)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jose\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Muestro el resultado de la lista de palabras relevantes
print(data_no_stopwords)
# Out:
# ['mensajes', 'apoyo', 'vallisoletanos', 'rehabilita', 'tecnología', 'zanja', 'red', 'alcantarillado', 'reventón', 'tubería', 'obliga', 'cortar', 'calle', 'olmo', 'analiza', 'domingos', 'residuales', 'buscar', 'trazas', 'coronavirus', 'vallisoletanos', 'podrán', 'pagar', 'impuestos', 'municipales', 'correos', 'ayuntamiento', 'diseña', 'plan', 'prevenir', 'erradicar', 'acoso', 'laboral', 'empleados', 'reventón', 'anega', 'dos', 'locales', 'deja', '15', 'horas', 'dos', 'calles', 'rondilla', 'reventón', 'tubería', 'rondilla', 'anega', 'varios', 'locales', 'calle', 'linares', 'parques', 'infantiles', 'reabrirán', 'martes', 'promueve', 'consumo', 'grifo', 'hosteleros']

# %% [markdown]
# ### Análisis automatico de sentimientos con librería TextBlob (para idioma ingles)

# %%
## ANALISIS DE SENTIMIENTOS

# En ingles se usa la libreria TextBlob para analizar la polaridad de cada palabra en ingles
# La polaridad modifica el valor de sentimeniento que dará al final el texto
# Pero en español esta libreria no tiene una clasificacion de palabras, hay que traducirlas

# En primer lugar inicializamos el marcador para la puntuación de sentimientos
sentiment = 0

# Recorro la lista traduciendo de una en una al inglés (trabaja con palabras o frases, no con listas)

for word in data_no_stopwords:
    # Traduzco la palabra del español al inglés y analizo el sentimiento
    # Para evitar que se interrumpa la ejecución en caso de error defino control de intento
    try:
        # El resultado del análisis es un objeto TextBlob
        analysis = TextBlob(word).translate(from_lang='es', to='en')
    except:
        # si no puede traducir la palabra, la analizo sin traducir
        analysis = TextBlob(word)
    
    # Muestro como trabaja el análisis
    print(word, " - ", analysis, " - ", analysis.sentiment.polarity)
    
    # Analizo el 'objeto TextBlob' con la palabra traducida
    if analysis.sentiment.polarity > 0:
        sentiment += 1
    elif analysis.sentiment.polarity == 0:
        sentiment = sentiment
    else:
        sentiment -= 1
        
print("Puntuación final: ", sentiment)
# Out:
# mensajes  -  posts  -  0.0
# apoyo  -  support for  -  0.0
# vallisoletanos  -  Valladolid  -  0.0
# rehabilita  -  rehabilitates  -  0.0
# tecnología  -  technology  -  0.0
# zanja  -  ditch  -  0.0
# red  -  net  -  0.0
# alcantarillado  -  sewerage  -  0.0
# reventón  -  blowout  -  0.0
# tubería  -  pipeline  -  0.0
# obliga  -  obliges  -  0.0
# cortar  -  cut  -  0.0
# calle  -  Street  -  0.0
# olmo  -  elm  -  0.0
# analiza  -  analyze  -  0.0
# domingos  -  Sundays  -  0.0
# residuales  -  residual  -  0.0
# buscar  -  search for  -  0.0
# trazas  -  traces  -  0.0
# coronavirus  -  coronavirus  -  0.0
# vallisoletanos  -  Valladolid  -  0.0
# podrán  -  will be able  -  0.5
# pagar  -  pay  -  0.0
# impuestos  -  taxes  -  0.0
# municipales  -  municipal  -  0.0
# correos  -  post  -  0.0
# ayuntamiento  -  town hall  -  0.0
# diseña  -  designs  -  0.0
# plan  -  plan  -  0.0
# prevenir  -  to prevent  -  0.0
# erradicar  -  eradicate  -  0.0
# acoso  -  bullying  -  0.0
# laboral  -  labor  -  0.0
# empleados  -  employees  -  0.0
# reventón  -  blowout  -  0.0
# anega  -  flooded  -  0.0
# dos  -  two  -  0.0
# locales  -  local  -  0.0
# deja  -  let  -  0.0
# 15  -  fifteen  -  0.0
# horas  -  hours  -  0.0
# dos  -  two  -  0.0
# calles  -  streets  -  0.0
# rondilla  -  rondilla  -  0.0
# reventón  -  blowout  -  0.0
# tubería  -  pipeline  -  0.0
# rondilla  -  rondilla  -  0.0
# anega  -  flooded  -  0.0
# varios  -  various  -  0.0
# locales  -  local  -  0.0
# calle  -  Street  -  0.0
# linares  -  linares  -  0.0
# parques  -  parks  -  0.0
# infantiles  -  infantile  -  -0.4
# reabrirán  -  will reopen  -  0.0
# martes  -  Tuesday  -  0.0
# promueve  -  promotes  -  0.0
# consumo  -  consumption  -  0.0
# grifo  -  tap  -  0.0
# hosteleros  -  hoteliers  -  0.0
# Puntuación final:  0

# %% [markdown]
# ### Análisis de sentimientos con nuestra propia lista de palabras en español
#
# Vemos que la puntuación final es nuetra, porque ha encontrado el mismo número de palabras que una vez traducidas considera negativas, que de positivas.
#
# Para mejorar el análisis en español, y en una aplicación específica, lo mejor es definir nuestras propias listas de palabras.

# %%
# Creamos listas de palabras positivas y negativas para valorar las noticias relativas al sector del agua
pal_posit = ['bueno', 'excelente', 'rapido', 'eficaz', 'eficiente', 'restablecer', 'restablece', 'recuperar', 'recupera', 'concluir', 'invertir', 'inversión', 'invierte', 'mejora', 'reforma', 'primera', 'multiplica', 'reurbaniza', 'rehabilita', 'valor', 'valorizar', 'revalorizar', 'sostenible', 'gana', 'beneficios', 'beneficia', 'prevenir', 'diseñar', 'diseña', 'analiza', 'promover', 'promueve', 'tecnología']
pal_neg = ['averia', 'reventón', 'rotura', 'inundacion', 'inundar', 'inunda', 'fuga', 'balsa', 'malo', 'peor', 'corte', 'cortar', 'desabastecido', 'desastre', 'desastroso', 'suspenso', 'suspendidas', 'equivocación', 'equivocarse', 'error', 'errar', 'imprevisto', 'poco', 'poca', 'falta', 'obliga', 'impuestos']

# Creamos una lista ordenada con todos los elementos unicos que aparecen en el texto original
palabras = sorted(list(set(data_no_stopwords)))

print(palabras)
# Out:
# ['15', 'acoso', 'alcantarillado', 'analiza', 'anega', 'apoyo', 'ayuntamiento', 'buscar', 'calle', 'calles', 'consumo', 'coronavirus', 'correos', 'cortar', 'deja', 'diseña', 'domingos', 'dos', 'empleados', 'erradicar', 'grifo', 'horas', 'hosteleros', 'impuestos', 'infantiles', 'laboral', 'linares', 'locales', 'martes', 'mensajes', 'municipales', 'obliga', 'olmo', 'pagar', 'parques', 'plan', 'podrán', 'prevenir', 'promueve', 'reabrirán', 'red', 'rehabilita', 'residuales', 'reventón', 'rondilla', 'tecnología', 'trazas', 'tubería', 'vallisoletanos', 'varios', 'zanja']

# %%
# Comparamos entre listas
loc_posit = set(palabras).intersection(pal_posit)
print("Palabras positivas localizadas: ", loc_posit)

loc_neg = set(palabras).intersection(pal_neg)
print("Palabras positivas localizadas: ", loc_neg)
# Out:
# Palabras positivas localizadas:  {'tecnología', 'promueve', 'rehabilita', 'prevenir', 'analiza', 'diseña'}
# Palabras positivas localizadas:  {'reventón', 'cortar', 'obliga', 'impuestos'}

# %%
# Obtenemos la puntuación como diferencia de longitudes entre las listas de palabras localizadas
sentimiento = len(loc_posit)-len(loc_neg)
print("Puntuacion final: ", sentimiento)

# También podemos ver el grado de sensibilidad en función de opiniones predominantes respecto del total
print("% sensibilidad: ", 100*max(abs(len(loc_posit)), abs(len(loc_neg)))/(len(loc_posit)+len(loc_neg)))
# Out:
# Puntuacion final:  2
# % sensibilidad:  60.0
